# %% [markdown]
# 1.  What is NumPy, and why is it widely used in Python?
# - NumPy, or Numerical Python, is a Python library that supports large multi-dimensional arrays and mathematical functions.
# - It's a key part of scientific computing in Python, and is used in data analysis, machine learning, and research.
# - **Fast**-  NumPy is faster than regular Python arrays because it's optimized and pre-compiled with C code.
# - **Open source:** NumPy is free and open-source software.
# - **Supports large arrays:** NumPy can handle large arrays, which are also called matrices or tensors.
# 2. How does broadcasting work in NumPy ?
# - Broadcasting simplifies mathematical operations on arrays with different shapes.
# -  It enables NumPy to efficiently apply operations element-wise without explicitly copying or reshaping data.
# - The term broadcasting describes how NumPy treats arrays with different shapes during arithmetic operations.
# 3. What is a Pandas DataFrame?
# - Pandas DataFrame is a way to represent and work with tabular data.
# - A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
# 4. Explain the use of the groupby() method in Pandas?
# - The groupby() function in Pandas is used to split a DataFrame into groups based on some criteria.
# - The groupby() function in Pandas involves three main steps: Splitting, Applying, and Combining.
# - **Splitting:** This step involves dividing the DataFrame into groups based on some criteria. The groups are defined by unique values in one or more columns.
# - **Applying**: In this step, a function is applied to each group independently. You can apply various functions to each group.
# 5. Why is Seaborn preferred for statistical visualizations?
# - Seaborn is built on top of Matplotlib and provides a higher-level interface for creating statistical graphics. This means that Seaborn requires less code to create complex visualizations compared to Matplotlib.
# - Seaborn is a Python library that's used to create attractive and informative statistical graphics. It's commonly used for data science and machine learning tasks.
# - Multi-plot visualizations
# Seaborn can create grids of plots that allow for easy comparison between multiple variables or subsets of data.
# 6. What are the differences between NumPy arrays and Python lists?
# - NumPy arrays are much faster and have strict requirements on the homogeneity of the objects.
# - Lists can hold different data types, but this can decrease memory efficiency and slow numerical operations.
# - NumPy arrays have a fixed data type, reducing memory overhead by eliminating the need to store type information for each element.
# - NumPy arrays store elements of the same data type, making them more compact and memory-efficient than lists.
# 7. What is a heatmap, and when should it be used?
# - A heatmap is a data visualization tool that uses color to show how values vary across two axes. Heatmaps can be used to identify patterns, correlations, and trends in data.
# - **Compare and contrast**
# Use heatmaps to compare and contrast different groups or categories of data.
# - **Assess strengths and weaknesses**
# Use heatmaps to identify an organization's strengths and weaknesses.
# 8. What does the term “vectorized operation” mean in NumPy?
# - Vectorization in NumPy is a method of performing operations on entire arrays without explicit loops.
# - By replacing iterative processes with vectorized functions, you can significantly optimize performance in data analysis, machine learning, and scientific computing tasks.
# 9. How does Matplotlib differ from Plotly?
# - Matplotlib is more explicit in declaring each plot element, making it an ideal place for new Python users to start, while Plotly is well-suited for creating interactive plots to be displayed in a web browser.
# - Matplotlib offers unmatched control and is perfect for creating static, publication-quality visuals. Plotly, on the other hand, excels in interactivity and ease of use, making it ideal for dynamic presentations and web applications.
# 10. What is the significance of hierarchical indexing in Pandas ?
# - Hierarchical indexing is one of the functions in pandas, a software library for the Python programming languages. pandas derives its name from the term “panel data”, a statistical term for four-dimensional data models that show changes over time.
# - Hierarchical Indexes are also known as multi-indexing is setting more than one column name as the index.
# - We may sometimes need to make a column as an index, or we want to convert an index column into the normal column, so there is a pandas reset_index(inplace = True) function, which makes the index column the normal column.
# 11. What is the role of Seaborn’s pairplot() function?
# - Seaborn's pairplot() function creates a grid of scatterplots, visualizing the pairwise relationships between every numerical variable in a dataset, effectively allowing you to explore the distribution of individual variables and the correlations between them within a single plot, making it a valuable tool for exploratory data analysis (EDA).
# - **Identifying patterns and outliers:**
# By looking at the scatterplots, you can quickly identify potential trends, correlations, and outliers in your data.
# - **Customization options:**
# You can control the type of plot on the diagonal, add color coding based on a categorical variable (using the hue parameter), and adjust plot styles for better visualization.
# 12. What is the purpose of the describe() function in Pandas
# - The describe() function in pandas is used to get a quick summary of a DataFrame's data. It provides descriptive statistics for a DataFrame's columns.
# - By default, describe() works with numeric data but can also handle categorical data
# - The output will vary depending on what is provided
# - You can adjust the function with custom percentiles and inclusive parameters for various data types.
# 13. Why is handling missing data important in Pandas?
# - **Impacts analysis accuracy:**
# Missing data can significantly affect the results of statistical calculations and machine learning models if not handled properly.
# - **Data cleaning necessity:**
# Before conducting any analysis, it's essential to identify and address missing values to ensure your dataset is clean and reliable.
# - **Pandas functionalities:**
# Pandas provides convenient tools like fillna() to replace missing values with a specified value (like the mean or median) and dropna() to remove rows or columns with missing data.
# 14. What are the benefits of using Plotly for data visualization?
# - Plotly and ggplot2 are popular data visualization libraries, each with its unique features, benefits, and drawbacks.
# - Plotly offers users control over what is being plotted, simple syntax, enhanced interactivity, extensive support community, compatibility with multiple languages, and the ability to share plots online.
# 15. How does NumPy handle multidimensional arrays ?
# - A NumPy array is a homogeneous block of data organized in a multidimensional finite grid.
# - A multi-dimensional array is an array with more than one level or dimension. For example, a 2D array, or two-dimensional array, is an array of arrays, meaning it is a matrix of rows and columns (think of a table). A 3D array adds another dimension, turning it into an array of arrays of arrays.
# 16. What is the role of Bokeh in data visualization?
# - Bokeh is a data visualization library in Python that provides high-performance interactive charts and plots.
# - Bokeh output can be obtained in various mediums like notebook, html and server. It is possible to embed bokeh plots in Django and flask apps.
# 17. Explain the difference between apply() and map() in Pandas?
# - While map is great for simple element-wise transformations in Series, apply offers more flexibility for both Series and DataFrame objects.
# -  On the other hand, applymap excels at DataFrame-wide element-wise operations.
# - Defined only in Series	while other	Defined in both Series and DataFrame
# - **MAP**: Accepts dictionary, Series, or callable.
# - **APPLY**: Accept callables only.
# 18. What are some advanced features of NumPy?
# - Some advanced features of NumPy include linear algebra, broadcasting, and random number generation.
# - NumPy can perform complex linear algebra tasks like matrix multiplication, finding eigenvalues, and solving systems of equations
# - Broadcasting is a technique that allows NumPy to work with arrays of different shapes
# - When performing arithmetic operations, NumPy broadcasts the smaller array across the larger array so that they have compatible shapes
# 19. How does Pandas simplify time series analysis?
# - Although the time series is also available in the Scikit-learn library, data science professionals use the Pandas library as it has compiled more features to work on the DateTime series. We can include the date and time for every record and can fetch the records of DataFrame.
# - Create a series of date
# - Work with data timestamp
# - Convert string data to timestamp
# - Slicing of data using timestamp
# - Resample your time series for different time period aggregates/summary
# - statistics
# - Working with missing data
# 20. What is the role of a pivot table in Pandas?
# - Pandas' pivot_table function operates similar to a spreadsheet, making it easier to group, summarize and analyze your data.
# - Here's how to create your own. The pandas library is a popular Python package for data analysis.
# - The pivot table takes simple column-wise data as input, and groups the entries into a two-dimensional table that provides a multidimensional summarization of the data.
# 21. Why is NumPy’s array slicing faster than Python’s list slicing?
# - NumPy arrays provide a significant speed advantage over traditional lists. This is because NumPy is built in C and uses optimized, pre-compiled code for numerical operations.
# - This allows for vectorization, which means operations are applied to all elements in an array without the need for explicit loops in Python.
# - NumPy's main data object is an array, specifically ndarray. These ndarrays are significantly faster than the list-based arrays in Python since no looping is required.
# - In Pandas, the primary data objects are DataFrames and series, equivalent to a one-dimensional array.
#
# 22. What are some common use cases for Seaborn?
# - Data visualization can be done by seaborn and it can transform complex datasets into clear visual representations making it easier to understand, identify trends and relationships within the data.
# - **High-level interface:** Simplifies the creation of complex visualizations.
# - **Integration with Pandas:** Works with Pandas DataFrames for data manipulation.
# - **Built-in themes:** Offers attractive default themes and color palettes.
# Statistical plots: Provides various plot types to visualize statistical relationships and distributions.

# %%
#1. How do you create a 2D NumPy array and calculate the sum of each row?
import numpy as np
arr =np.array([[1,2,3],[4,5,6]])
arr
print(np.sum(arr))
print(np.sum(arr,axis=1))
# Out:
# 21
# [ 6 15]

# %%
#2. Write a Pandas script to find the mean of a specific column in a DataFrame?
import pandas as pd
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
print(df)
print(df.mean())
print(df.mean(axis=1))
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# A    2.0
# B    5.0
# dtype: float64
# 0    2.5
# 1    3.5
# 2    4.5
# dtype: float64

# %%
#3.Create a scatter plot using Matplotlib.
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.scatter(x,y)
plt.show()

# %%
#4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb
data = pd.read_csv("titanic.csv")
print(data.corr(numeric_only=True))
dataplot = sb.heatmap(data.corr(numeric_only=True), cmap="YlGnBu", annot=True)
mp.show()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#5.$A Generate a bar plot using Plotly.
import plotly.express as px
px.bar(x=[1,2,3],y=[4,5,6])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#6. Create a DataFrame and add a new column based on an existing column.
import pandas as pd
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df['C']=df['A']+df['B']
df
# Out:
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9

# %%
#7. Write a program to perform element-wise multiplication of two NumPy arrays.
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
print(a*b)
# Out:
# [ 4 10 18]

# %%
#8. Create a line plot with multiple lines using Matplotlib.
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
#9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold.
import pandas as pd
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
print(df[df['A']>1])
# Out:
#    A  B
# 1  2  5
# 2  3  6

# %%
#10. Create a histogram using Seaborn to visualize a distribution.
import seaborn as sb
sb.histplot([1,2,3,4,5])
# Out:
# <Axes: ylabel='Count'>

# %%
#11. Perform matrix multiplication using NumPy.
import numpy as np
a= np.array([[1,2,3],[4,5,6]])
b = np.array([[4,5],[6,7],[7,5]])
print(np.dot(a,b))
# Out:
# [[37 34]
#  [88 85]]

# %%
#12. Use Pandas to load a CSV file and display its first 5 rows.
import pandas as pd
df=pd.read_csv("Bank_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#13. Create a 3D scatter plot using Plotly.
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
